# %% [markdown]
# # Marking Oracles
#
# Quantum oracles are a key part of many quantum algorithms that rely on a quantum implementation of a classical function. The algorithms' discussions often assume that the quantum oracle that implements the function of interest is provided.
# However, in practice implementing a quantum oracle for a specific problem can be quite challenging.
#
# This kata continues the exploration of quantum oracles started in the Oracles kata, offering you a variety of practice problems on implementing marking oracles. If you're not familiar with the concept of quantum oracles, make sure to check out the Oracles kata that introduces the key concepts in this topic and offers a lot of simple practice problems.
#
# **This kata covers the following topics:**
#
# - Implementation of marking oracles for different classical functions
#
# **What you should know to start working on this kata:**
#
# - Fundamental quantum concepts
# - Controlled gates
# - Oracles, in particular marking oracles
#
# In each problem, you are given a description of a classical function $f(x)$ that should be implemented as a marking oracle. As usual with reversible computations, the effect of the unitary oracle is defined via its effect on basis states. Given a basis state $\ket{x}$, the oracle should flip the state of the target qubit $\ket{y}$ if $f(x) = 1$, and leave it unchanged otherwise.
# Leave the qubits in the input register in the same state they started in.
# Your solution should work on inputs in superposition, use no measurements, and not iterate over all possible inputs $x$.
#
# The input register $\ket{x}$ is treated either as an array of bits $\ket{x_0x_1...x_{N-1}}$ or, in later problems, as a single integer in little-endian notation $x = x_0 + 2 x_1 + 2^2 x_2 + ... + 2^{N-1} x_{N-1}$.

# %%
# Execute this cell to prepare the test infrastructure
from psiqdk.workbench import Qubits
from test_MarkingOracles import problem

# %% [markdown]
# ## Problem 1. K-th bit
#
# **Inputs:**
#
# 1. A Qubits register of length $N$ in an arbitrary superposition state $\ket{x}$ (the input register $\ket{x}$).
# 2. A Qubits register of length 1 in an arbitrary superposition state (the output register $\ket{y}$).
# 3. An integer $k$ such that $0 \le k < N$.
#
# **Goal:**
# Implement a marking oracle which calculates the $k$-th bit of the input register, that is, the function
# $$f(x) = x_k$$

# %%
@problem
def oracle_kth_bit(x: Qubits, y: Qubits, k: int) -> None:
    # Write your code here
    ...

# %% [markdown]
# ## Problem 2. Parity function
#
# **Inputs:**
#
# 1. A Qubits register of length $N$ in an arbitrary superposition state $\ket{x}$ (the input register $\ket{x}$).
# 2. A Qubits register of length 1 in an arbitrary superposition state (the output register $\ket{y}$).
#
# **Goal:**
# Implement a marking oracle which calculates the parity of the input array, that is, the function
# $$f(x) = 1 \text{ if } x \text{ has an odd number of 1s, and } 0 \text{ otherwise }$$
#
# <details>
# <summary><strong>Need a hint?</strong></summary>
#
# The function can be represented as $f(x) = x_0 \oplus x_1 \oplus ... \oplus x_{N-1}$.
# </details>

# %%
@problem
def oracle_parity(x: Qubits, y: Qubits) -> None:
    # Write your code here
    ...

# %% [markdown]
# ## Problem 3. Product function
#
# **Inputs:**
#
# 1. A Qubits register of length $N$ in an arbitrary superposition state $\ket{x}$ (the input register $\ket{x}$).
# 2. A Qubits register of length 1 in an arbitrary superposition state (the output register $\ket{y}$).
# 3. A bit vector $r$ of length $N$ represented as a `list[bool]`.
#
# **Goal:**
# Implement a marking oracle which calculates the scalar product function
# $$f(x) = \bigoplus\limits_{i=0}^{N-1} r_i x_i$$

# %%
@problem
def oracle_product(x: Qubits, y: Qubits, r: list[bool]) -> None:
    # Write your code here
    ...

# %% [markdown]
# ## Problem 4. Product function with negation
#
# **Inputs:**
#
# 1. A Qubits register of length $N$ in an arbitrary superposition state $\ket{x}$ (the input register $\ket{x}$).
# 2. A Qubits register of length 1 in an arbitrary superposition state (the output register $\ket{y}$).
# 3. A bit vector $r$ of length $N$ represented as a `list[bool]`.
#
# **Goal:**
# Implement a marking oracle which calculates the following function
# $$f(x) = \bigoplus\limits_{i=0}^{N-1} \left(r_i x_i \oplus (1 - r_i) (1 - x_i) \right)$$
#
# <details>
# <summary><strong>Need a hint?</strong></summary>
#
# Since all addition is done modulo 2, you can evaluate the effect of each term independently.
# </details>

# %%
@problem
def oracle_product_negation(x: Qubits, y: Qubits, r: list[bool]) -> None:
    # Write your code here
    ...

# %% [markdown]
# ## Problem 5. Is bit string a palindrome?
#
# **Inputs:**
#
# 1. A Qubits register of length $N$ in an arbitrary superposition state $\ket{x}$ (the input register $\ket{x}$).
# 2. A Qubits register of length 1 in an arbitrary superposition state (the output register $\ket{y}$).
#
# **Goal:**
# Implement a marking oracle which checks whether the input register is a palindrome, i.e., implements the function
#
# $$f(x) = 1 \text{ if } x \text{ is a palindrome, and } 0 \text{ otherwise }$$
#
# A bit string $x_0x_1...x_{N-1}$ is a palindrome if it equals its reverse, or, in other words, its first bit $x_0$ equals its last bit $x_{N-1}$, its second bit $x_1$ equals its second-to-last bit $x_{N-2}$, and so on.
#
# For example, for $N = 3$ the input state $\ket{101}$ is a palindrome, and $\ket{001}$ is not.

# %%
@problem
def oracle_palindrome(x: Qubits, y: Qubits) -> None:
    # Write your code here
    ...

# %% [markdown]
# ## Problem 6. Is bit string periodic with period P?
#
# **Inputs:**
#
# 1. A Qubits register of length $N$ in an arbitrary superposition state $\ket{x}$ (the input register $\ket{x}$).
# 2. A Qubits register of length 1 in an arbitrary superposition state (the output register $\ket{y}$).
# 3. An integer $P$ such that $0 < P < N$.
#
# **Goal:**
# Implement a marking oracle which checks whether the input register is periodic with period $P$, i.e., for all $j$ between $0$ and $N - P - 1$, inclusive, $x_j = x_{j+P}$.
#
# For example, for $N = 3$ the bit string `[False, True, False]` is periodic with period $2$, despite its length not being even.

# %%
@problem
def oracle_periodic_p(x: Qubits, y: Qubits, p: int) -> None:
    # Write your code here
    ...

# %% [markdown]
# ## Problem 7. Is bit string periodic?
#
# **Inputs:**
#
# 1. A Qubits register of length $N > 1$ in an arbitrary superposition state $\ket{x}$ (the input register $\ket{x}$).
# 2. A Qubits register of length 1 in an arbitrary superposition state (the output register $\ket{y}$).
#
# **Goal:**
# Implement a marking oracle which checks whether the input register is periodic with any period, i.e., whether there exists a value $0 < P < N$ such that for all $j$ between $0$ and $N - P - 1$, inclusive, $x_j = x_{j+P}$.
#
# For example, for $N = 3$ the bit string `[False, True, False]` is periodic with period $2$, so the bit string is periodic.

# %%
@problem
def oracle_periodic(x: Qubits, y: Qubits) -> None:
    # Write your code here
    ...

# %% [markdown]
# ## Problem 8. Does bit string contain substring at position P?
#
# **Inputs:**
#
# 1. A Qubits register of length $N$ in an arbitrary superposition state $\ket{x}$ (the input register $\ket{x}$).
# 2. A Qubits register of length 1 in an arbitrary superposition state (the output register $\ket{y}$).
# 3. A bit string $pattern$ of length $K$ represented as a `list[bool]` ($1 \le K \le N$).
# 4. An integer $P$ such that $0 \le P < N - K$.
#
# **Goal:**
# Implement a marking oracle which checks whether the input register contains the given pattern starting at the given position, i.e., for all $j$ between $0$ and $K - 1$, inclusive, $pattern_j = x_{j+P}$. (Values `False` and `True` represent states $\ket{0}$ and $\ket{1}$, respectively).
#
# For example, for $N = 3$ the bit string `[False, True, False]` contains the pattern `[True, False]` of length $K = 2$ starting at index $P = 1$.

# %%
@problem
def oracle_contains_substring_at_p(x: Qubits, y: Qubits, pattern: list[bool], p: int) -> None:
    # Write your code here
    ...

# %% [markdown]
# ## Problem 9. Pattern matching
#
# **Inputs:**
#
# 1. A Qubits register of length $N$ in an arbitrary superposition state $\ket{x}$ (the input register $\ket{x}$).
# 2. A Qubits register of length 1 in an arbitrary superposition state (the output register $\ket{y}$).
# 3. A list $indices$ of length $K$ ($1 \le K \le N$) containing distinct indices in the input register (that is, for every $j$ $0 \le indices_j < N$).
# 4. A bit vector $pattern$ of length $K$ represented as a `list[bool]`.
#
# **Goal:**
# Implement a marking oracle which checks whether the input register matches the given pattern, i.e., the bits at the given indices match the corresponding bits in the pattern. (Values `False` and `True` represent states $\ket{0}$ and $\ket{1}$, respectively).
# The value of input register $x_{indices_j}$ should match the pattern element $pattern_j$ for all $j$ between $0$ and $K - 1$, inclusive.
#
# For example, for $N = 3$ the pattern `[False, True]` at indices `[0, 2]` would match two basis states: $\ket{001}$ and $\ket{011}$.

# %%
@problem
def oracle_pattern_matching(x: Qubits, y: Qubits, indices: list[int], pattern: list[bool]) -> None:
    # Write your code here
    ...

# %% [markdown]
# ## Problem 10. Does bit string contain substring?
#
# **Inputs:**
#
# 1. A Qubits register of length $N$ in an arbitrary superposition state $\ket{x}$ (the input register $\ket{x}$).
# 2. A Qubits register of length 1 in an arbitrary superposition state (the output register $\ket{y}$).
# 3. A bit string $pattern$ of length $K$ represented as a `list[bool]` ($1 \le K \le N$).
#
# **Goal:**
# Implement a marking oracle which checks whether the input register contains the given pattern, i.e., whether there exists a position $P$ such that for all $j$ between $0$ and $K - 1$, inclusive, $pattern_j = x_{j+P}$. (Values `False` and `True` represent states $\ket{0}$ and $\ket{1}$, respectively).
#
# For example, for $N = 3$ the bit string `[False, True, False]` contains the pattern `[True, False]` of length $K = 2$ (starting at index $P = 1$).

# %%
@problem
def oracle_contains_substring(x: Qubits, y: Qubits, pattern: list[bool]) -> None:
    # Write your code here
    ...

# %% [markdown]
# ## Problem 11. Is bit string balanced?
#
# **Inputs:**
#
# 1. A Qubits register of length $N$ in an arbitrary superposition state $\ket{x}$ (the input register $\ket{x}$).
# 2. A Qubits register of length 1 in an arbitrary superposition state (the output register $\ket{y}$).
#
# **Goal:**
# Implement a marking oracle which checks whether the input register is a balanced bit string, i.e., whether it contains exactly $N/2$ $0$'s and $N/2$ $1$'s. $N$ will be an even number.
#
# For example, for $N = 4$ basis states $\ket{0011}$ and $\ket{0101}$ are balanced, and $\ket{0010}$ and $\ket{1111}$ are not.

# %%
@problem
def oracle_balanced(x: Qubits, y: Qubits) -> None:
    # Write your code here
    ...

# %% [markdown]
# ## Problem 12. Majority function
#
# **Inputs:**
#
# 1. A Qubits register of length $N$ in an arbitrary superposition state $\ket{x}$ (the input register $\ket{x}$). $N$ will be one of the values $3, 5, 7$.
# 2. A Qubits register of length 1 in an arbitrary superposition state (the output register $\ket{y}$).
#
# **Goal:**
# Implement a marking oracle which calculates the majority function, i.e., $f(x) = 1$ if most of the bits in the bit string are $1$'s, and $0$ otherwise.
#
# For example, for $N = 3$ majority function for basis states $\ket{001}$ and $\ket{000}$ is $0$, and for $\ket{101}$ and $\ket{111}$ is $1$.

# %%
@problem
def oracle_majority(x: Qubits, y: Qubits) -> None:
    # Write your code here
    ...

# %% [markdown]
# ## Problem 13. Is bit sum divisible by 3?
#
# **Inputs:**
#
# 1. A Qubits register of length $N$ in an arbitrary superposition state $\ket{x}$ (the input register $\ket{x}$).
# 2. A Qubits register of length 1 in an arbitrary superposition state (the output register $\ket{y}$).
#
# **Goal:**
# Implement a marking oracle which checks whether the sum of bits in the bit string is divisible by $3$.
#
# For example, for $N = 3$ the only basis states that should be marked are $\ket{000}$ and $\ket{111}$.

# %%
@problem
def oracle_bit_sum_divisible_by_three(x: Qubits, y: Qubits) -> None:
    # Write your code here
    ...

# %% [markdown]
# ## Problem 14. Is the number divisible by 3?
#
# **Inputs:**
#
# 1. A Qubits register of length $N$ in an arbitrary superposition state $\ket{x}$ (the input register $\ket{x}$).
# 2. A Qubits register of length 1 in an arbitrary superposition state (the output register $\ket{y}$).
#
# **Goal:**
# Implement a marking oracle which checks whether the number represented by the bit string is divisible by $3$.
# Use little-endian notation to convert the bit string to an integer, i.e., the least significant bit is stored in `x[0]`.
#
# For example, for $N = 3$ the basis states that should be marked are $\ket{000} = \ket{0}$, $\ket{110} = \ket{3}$, and $\ket{011} = \ket{6}$.

# %%
@problem
def oracle_number_divisible_by_three(x: Qubits, y: Qubits) -> None:
    # Write your code here
    ...

# %% [markdown]
# ## Conclusion
#
# Congratulations! In this kata you've learned to build marking oracles for quantum algorithms.
#
# > Copyright (c) 2026 PsiQuantum
