# %% [markdown]
# # Distinguishing Orthogonal Quantum States
#
# This kata is designed to get you familiar with the concept of measurements and using them for analyzing quantum states.
# In it, you will practice distinguishing sets of states that are pairwise orthogonal.
# In this scenario, the states can be distinguished perfectly, with 100% accuracy.
#
# **This kata covers the following topics:**
#
# - Single-qubit measurements
# - Distinguishing orthogonal states
#
# **What you should know to start working on this kata:**
#
# - Dirac notation for single-qubit and multi-qubit quantum systems
# - Basic single-qubit and multi-qubit gates
# - Single-qubit quantum measurements and their effect on quantum systems

# %%
from psiqdk.workbench import Qubits
from test_DistinguishingStates import problem

# %% [markdown]
# ## Problem 1. Distinguish |00⟩ and |11⟩
#
# **Inputs:** A `Qubits` register of length $2$ which is guaranteed to be in either the $\ket{00}$ or the $\ket{11}$ state.
#
# **Goal:** Figure out which state the qubits are in:
#
# * $0$ if the qubits are in the $\ket{00}$ state.
# * $1$ if they are in the $\ket{11}$ state.

# %%
@problem
def zerozero_or_oneone(reg: Qubits) -> int:
    # Write your code here
    ...

# %% [markdown]
# ## Problem 2. Distinguish four basis states
#
# **Inputs:** **Inputs:** A `Qubits` register of length $2$ which is guaranteed to be in one of the four computational basis states.
#
# **Goal:** Figure out which state the qubits are in:
#
# * 0 if the qubits are in the $\ket{00}$ state,
# * 1 if they are in the $\ket{10}$ state,
# * 2 if they are in the $\ket{01}$ state,
# * 3 if they are in the $\ket{11}$ state.

# %%
@problem
def measure_basis_state(reg: Qubits) -> int:
    # Write your code here
    ...

# %% [markdown]
# ## Problem 3. Distinguish two basis states given by bit strings
#
# **Inputs:**
# 1. A `Qubits` register of length $N$ which is guaranteed to be in one of the two basis states described by the given bit strings.
# 2. Two bit strings of length $N$, represented as `list[bool]`s. Values `False` and `True` correspond to $\ket{0}$ and $\ket{1}$ states. You're guaranteed that the two bit strings differ in at least one bit.
#
# **Goal:** Figure out which state the qubits are in:
#
# * $0$ if the qubits are in the basis state described by the first bit string.
# * $1$ if they are in the basis state described by the second bit string.

# %%
@problem
def measure_two_bitstrings(reg: Qubits, bits0: list[bool], bits1: list[bool]) -> int:
    # Write your code here
    ...

# %% [markdown]
# ## Problem 4. Distinguish two superposition states given by lists of bit strings
#
# **Inputs:**
#
# 1. A `Qubits` register of length $N$ which is guaranteed to be in one of the two superposition states described by the given bit strings.
# 2. Two lists of bit strings of length $N$, represented as `list[list[bool]]`s. Values `False` and `True` correspond to $\ket{0}$ and $\ket{1}$ states. Each state is a superposition of all basis states in the corresponding list.
# You're guaranteed that all bit strings in the two lists are different.
#
# **Goal:** Figure out which state the qubits are in:
#
# * $0$ if the qubits are in the superposition state described by `bits0`.
# * $1$ if they are in the superposition state described by `bits1`.
#
#
# > For example, for bit strings `[[False, True, False], [False, False, True]]` and `[[True, True, True], [False, True, True]]` return $0$ corresponds to state
# $\tfrac{1}{\sqrt2}\big(\ket{010} + \ket{001}\big)$,
# return $1$ - to state
# $\tfrac{1}{\sqrt2}\big(\ket{111} + \ket{011}\big)$.

# %%
@problem
def measure_four_bitstring_superpositions(reg: Qubits, bits0: list[list[bool]], bits1: list[list[bool]]) -> int:
    # Write your code here
    ...

# %% [markdown]
# ## Problem 5. Distinguish two superposition states given by lists of bit strings in one measurement
#
# **Inputs:**
#
# 1. A `Qubits` register of length $N$ which is guaranteed to be in one of the two superposition states described by the given bit strings.
# 4. Two lists of bit strings of length $N$, represented as `list[list[bool]]`s. Values `False` and `True` correspond to $\ket{0}$ and $\ket{1}$ states. Each state is a superposition of all basis states in the corresponding list.
#
# Furthermore, you are guaranteed that there exists an index of a qubit Q for which:
#
# * All the bit strings in the first array have the same value in this position (all `bits0[j][Q]` are the same).
# * All the bit strings in the second array have the same value in this position (all `bits1[j][Q]` are the same).
# * These values are different for the first and the second arrays.
#
# **Goal:** Figure out which state the qubits are in:
#
# * $0$ if the qubits are in the superposition state described by `bits0`.
# * $1$ if they are in the superposition state described by `bits1`.
#
# > For example, for arrays `[[False, True, False], [False, True, True]]` and `[[True, False, True], [False, False, True]]` return $0$ corresponds to state $\frac{1}{\sqrt2}\big(\ket{010} + \ket{011}\big)$, return $1$ corresponds to state $\frac{1}{\sqrt2}\big(\ket{101} + \ket{001}\big)$, and you can distinguish these states perfectly by measuring the second qubit ($Q = 1$).
#
# **You are allowed to use exactly one measurement.**

# %%
@problem
def measure_four_bitstring_superpositions_one(reg: Qubits, bits0: list[list[bool]], bits1: list[list[bool]]) -> int:
    # Write your code here
    ...

# %% [markdown]
# ## Problem 6. Distinguish |0...0⟩ state and W state
#
# **Inputs:** A `Qubits` register of length $N$ which is guaranteed to be either in the $\ket{0...0}$ state or in the W state - an equal superposition of all $N$ basis states that have exactly one $\ket{1}$ in them.
#
# For example, for $N = 3$ the W state is $\frac1{\sqrt3} (\ket{100} + \ket{010} + \ket{001})$.
#
# **Goal:** Figure out which state the qubits are in:
#
# * $0$ if the qubits are in the $\ket{0...0}$ state.
# * $1$ if they are in the W state.

# %%
@problem
def zero_or_wstate(reg: Qubits) -> int:
    # Write your code here
    ...

# %% [markdown]
# ## Problem 7. Distinguish GHZ state and W state
#
# **Inputs:** A `Qubits` register of length $N$ which is guaranteed to be
# * either in the GHZ state - an equal superposition of $\ket{0...0}$ and $\ket{1...1}$ states
# * or in the W state - an equal superposition of all $N$ basis states that have exactly one $\ket{1}$ in them.
#
# For example, for $N = 3$ the GHZ state is $\frac1{\sqrt2}(\ket{000} + \ket{111})$, and the W state is $\frac1{\sqrt3} (\ket{100} + \ket{010} + \ket{001})$.
#
# **Goal:** Figure out which state the qubits are in:
#
# * $0$ if the qubits are in the GHZ state.
# * $1$ if they are in the W state.

# %%
@problem
def ghz_or_wstate(reg: Qubits) -> int:
    # Write your code here
    ...

# %% [markdown]
# ## Problem 8. Distinguish four Bell states
#
# **Inputs:** A `Qubits` register of length $2$ which is guaranteed to be in one of the four Bell states.
#
# **Goal:** Figure out which state the qubits are in:
#
# * $0$ if they are in the state $\ket{\Phi^{+}} = \frac{1}{\sqrt{2}} \big(\ket{00} + \ket{11}\big)$,
# * $1$ if they are in the state $\ket{\Phi^{-}} = \frac{1}{\sqrt{2}} \big(\ket{00} - \ket{11}\big)$,
# * $2$ if they are in the state $\ket{\Psi^{+}} = \frac{1}{\sqrt{2}} \big(\ket{01} + \ket{10}\big)$,
# * $3$ if they are in the state $\ket{\Psi^{-}} = \frac{1}{\sqrt{2}} \big(\ket{01} - \ket{10}\big)$.

# %%
@problem
def measure_bell_states(reg: Qubits) -> int:
    # Write your code here
    ...

# %% [markdown]
# ## Problem 9. Distinguish four separable two-qubit states
#
# **Inputs:** A `Qubits` register of length $2$ which is guaranteed to be in one of the four orthogonal states.
#
# **Goal:** Figure out which state the qubits are in:
#
# * $0$ if they are in the state
#   $\ket{S_0} = \frac{1}{2} \big(\ket{00} + \ket{01} + \ket{10} + \ket{11}\big)$,
# * $1$ if they are in the state
#   $\ket{S_1} = \frac{1}{2} \big(\ket{00} + \ket{01} - \ket{10} - \ket{11}\big)$,
# * $2$ if they are in the state
#   $\ket{S_2} = \frac{1}{2} \big(\ket{00} - \ket{01} + \ket{10} - \ket{11}\big)$,
# * $3$ if they are in the state
#   $\ket{S_3} = \frac{1}{2} \big(\ket{00} - \ket{01} - \ket{10} + \ket{11}\big)$.

# %%
@problem
def measure_twoqubit_separable_states(reg: Qubits) -> int:
    # Write your code here
    ...

# %% [markdown]
# ## Problem 10. Distinguish four entangled two-qubit states
#
# **Inputs:** A `Qubits` register of length $2$ which is guaranteed to be in one of the four orthogonal states.
#
# **Goal:** Figure out which state the qubits are in:
#
# * $0$ if they are in the state
#   $\ket{S_0} = \frac{1}{2} \big(-\ket{00} + \ket{10} + \ket{01} + \ket{11}\big)$,
# * $1$ if they are in the state
#   $\ket{S_1} = \frac{1}{2} \big(+\ket{00} - \ket{10} + \ket{01} + \ket{11}\big)$,
# * $2$ if they are in the state
#   $\ket{S_2} = \frac{1}{2} \big(+\ket{00} + \ket{10} - \ket{01} + \ket{11}\big)$,
# * $3$ if they are in the state
#   $\ket{S_3} = \frac{1}{2} \big(+\ket{00} + \ket{10} + \ket{01} - \ket{11}\big)$.

# %%
@problem
def measure_twoqubit_entangled_states(reg: Qubits) -> int:
    # Write your code here
    ...

# %% [markdown]
# ## Problem 11. Distinguish two three-qubit states
#
# **Inputs:** A `Qubits` register of length $3$ which is guaranteed to be in one of the two orthogonal states.
#
# **Goal:** Figure out which state the qubits are in:
#
# * $0$ if they are in the state
#   $\ket{S_0} = \frac{1}{\sqrt{3}} \big(\ket{100} + \omega \ket{010} + \omega^2 \ket{001} \big)$,
# * $1$ if they are in the state
#   $\ket{S_1} = \frac{1}{\sqrt{3}} \big(\ket{100} + \omega^2 \ket{010} + \omega \ket{001} \big)$.
#
# Here $\omega = e^{2i \pi/3}$.

# %%
@problem
def measure_threequbit_states(reg: Qubits) -> int:
    # Write your code here
    ...

# %% [markdown]
# # Conclusion
#
# Congratulations! In this kata you learned to use measurements and basic quantum computing gates to distinguish orthogonal quantum states.
#
# > Copyright (c) 2026 PsiQuantum
