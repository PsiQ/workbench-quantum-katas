# %% [markdown]
# # Distinguishing Non-orthogonal Quantum States
#
# This kata is an advanced topic extended from Distinguishing Orthogonal States kata.
# In it, you will practice distinguishing sets of states that are not orthogonal orthogonal.
# In this scenario, the states distinguishment are probablistic, with chances of failing or inconclusive.
#
# **This kata covers the following topics:**
#
# - Distinguishing non-orthogonal states
#
# **What you should know to start working on this kata:**
#
# - Dirac notation for single-qubit and multi-qubit quantum systems
# - Basic single-qubit and multi-qubit gates
# - Single-qubit and multi-qubit quantum measurements and their effect on quantum systems

# %%
from psiqdk.workbench import Qubits
from test_DistinguishingNonOrthogonalStates import problem

# %% [markdown]
# ## Problem 1. Distinguish $\ket{0}$ and $\ket{+}$
#
# **Input:** A `Qubits` register with length 1 which is guaranteed to be in either the $\ket{0}$ or the $\ket{+}$ state.
#
# **Output:** 0 if the qubit was in the $\ket{0}$ state, or 1 if it was in the $\ket{+}$ state. The state of the qubit at the end of the operation does not matter.
#
# In this task your solution will be called multiple times, with one of the states picked with equal probability every time. You have to get overall accuracy of at least 80%.
#
# > This task is an example of quantum hypothesis testing, or state discrimination with minimum error.

# %%
@problem
def measure_zero_or_plus(reg: Qubits) -> int:
    # Write your code here
    ...

# %% [markdown]
# ## Problem 2. $\ket{0}$, $\ket{+}$, or inconclusive?
#
# **Input:** A `Qubits` register of length 1 which is guaranteed to be in either the $\ket{0}$ or the $\ket{+}$ state.
#
# **Output:**
# * 0 if the qubit was definitely in the $\ket{0}$ state,
# * 1 if it was definitely in the $\ket{+}$ state,
# * -1 if you can't decide, i.e., an "inconclusive" result.
#
# Your solution:
#
# * should never give 0 or 1 answer incorrectly (i.e., identify $\ket{0}$ as 1 or $\ket{+}$ as 0),
# * will be called multiple times, with one of the states picked with equal probability every time,
# * may give an inconclusive (-1) answer in at most 80% of all the cases,
# * must correctly identify the $\ket{0}$ state as 0 in at least 10% of all the cases,
# * must correctly identify the $\ket{1}$ state as 1 in at least 10% of all the cases.
#
# The state of the qubit at the end of the operation does not matter.
#
# > This task is an example of unambiguous state discrimination.
#
# <details>
#   <summary><b>Need a hint?</b></summary>
#
# It is easy to figure out a measurement that is never wrong when recognizing the $\ket{+}$ state but cannot identify the $\ket{0}$ state, or another measurement that acts the other way around. Can you combine these two strategies?
# </details>

# %%
@problem
def measure_zero_or_plus_or_inconclusive(reg: Qubits) -> int:
    # Write your code here
    ...

# %% [markdown]
# ## Problem 3. Peres/Wooters game
#
# **Input:** A `Qubits` register of length 1 which is guaranteed to be in one of the three states:
#
# * $\ket{A} = \frac{1}{\sqrt{2}} \big( \ket{0} + \ket{1} \big)$,
# * $\ket{B} = \frac{1}{\sqrt{2}} \big( \ket{0} + \omega \ket{1} \big)$,
# * $\ket{C}= \frac{1}{\sqrt{2}} \big( \ket{0} + \omega^2 \ket{1} \big)$,
#
# Here $\omega = e^{2i \pi/ 3}$.
#
# **Output:**
#
# * 1 or 2 if the qubit was in the $\ket{A}$ state,
# * 0 or 2 if the qubit was in the $\ket{B}$ state,
# * 0 or 1 if the qubit was in the $\ket{C}$ state.
#
# You are never allowed to give an incorrect answer. Your solution will be called multiple times, with one of the states picked with equal probability every time.
#
# The state of the qubit at the end of the operation does not matter.
#
# <details>
#   <summary><b>Need a hint?</b></summary>
#
# You can use an auxiliary qubit in your solution.
# </details>

# %%
@problem
def peres_wooters_game(reg: Qubits) -> int:
    # Write your code here
    ...

# %% [markdown]
# # Conclusion
#
# Congratulations! In this kata you learned to use measurements and basic quantum computing gates to distinguish non-orthogonal quantum states.
#
# > Copyright (c) 2026 PsiQuantum
